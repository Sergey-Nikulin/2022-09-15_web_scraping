# %% [markdown]
# # Домашнее задание к лекции "Основы веб-скрапинга"

# %% [markdown]
# ## Обязательная часть

# %% [markdown]
# Вам необходимо написать функцию, которая будет основана на **поиске** по сайту [habr.com](https://habr.com/ru/search/).
# Функция в качестве параметра должна принимать **список** запросов для поиска (например, `['python', 'анализ данных']`) и на основе материалов, попавших в результаты поиска по **каждому** запросу, возвращать датафрейм вида:
#
# ```
# <дата> - <заголовок> - <ссылка на материал>
# ```
#
# В рамках задания предполагается работа только с одной (первой) страницей результатов поисковой выдачи для каждого запроса. Материалы в датафрейме не должны дублироваться, если они попадали в результаты поиска для нескольких запросов из списка.

# %%
import requests
from bs4 import BeautifulSoup 
import time
import pandas as pd
#time.sleep(0.2)

# %%
# KEYWORDS = ['python', 'анализ данных']
def get_habr():
    params = { 'q': ['python', 'анализ данных'] }
    
    url = requests.get('https://habr.com/ru/search', params = params)
    soup = BeautifulSoup(url.text)
    # soup
    articles = soup.find_all('div', class_='tm-article-snippet')
    hubr_news = pd.DataFrame()
    for article in articles:
        title = article.find('a', class_='tm-article-snippet__title-link').text
        link = article.find('a', class_='tm-article-snippet__title-link').get('href')
        date = article.find('span', class_='tm-article-snippet__datetime-published').text.strip()
        row = {'date': date, 'title': title, 'link': link}
        hubr_news = pd.concat([hubr_news, pd.DataFrame([row])])
    return hubr_news.reset_index()
get_habr()
# Out:
#     index                        date  \
# 0       0   10  декабря  2021 в 13:15
# 1       0      27  июня  2017 в 13:51
# 2       0      30  июня  2017 в 10:52
# 3       0           9  июня   в 21:30
# 4       0        6  мая  2021 в 06:01
# 5       0  22  сентября  2020 в 16:43
# 6       0   18  октября  2021 в 15:08
# 7       0      30  июня  2014 в 23:06
# 8       0  14  сентября  2014 в 19:54
# 9       0    23  ноября  2014 в 16:49
# 10      0    18  января  2015 в 18:02
# 11      0   11  августа  2014 в 10:47
# 12      0    1  февраля  2015 в 15:55
# 13      0      18  июня  2014 в 15:19
# 14      0      28  июля  2014 в 13:10
# 15      0    2  октября  2017 в 10:56
# 16      0   23  октября  2017 в 01:42
# 17      0          4  марта   в 19:00
# 18      0      24  июля  2015 в 11:20
# 19      0   4  сентября  2017 в 10:50
#
#                                                 title  \
# 0   Интенсив для повышения квалификации: как испол...
# 1   Использование Python и Excel для обработки и а...
# 2   Использование Python и Excel для обработки и а...
# 3   Шаблон новичка на пути PANDAS в искусстве анал...
# 4       Python, исследование данных и выборы: часть 3
# 5   Напишем и поймем Decision Tree на Python с нул...
# 6   AI Journey Contest 2021: какие задачи мы подго...
# 7   Обзор наиболее интересных материалов по анализ...
# 8   Обзор наиболее интересных материалов по анализ...
# 9   Обзор наиболее интересных материалов по анализ...
# 10  Обзор наиболее интересных материалов по анализ...
# 11  Обзор наиболее интересных материалов по анализ...
# 12  Обзор наиболее интересных материалов по анализ...
# 13  Обзор наиболее интересных материалов по анализ...
# 14  Обзор наиболее интересных материалов по анализ...
# 15  3 кейса применения анализа данных в сфере недв...
# 16  «4 свадьбы и одни похороны» или линейная регре...
# 17        Основы теории вероятностей с помощью Python
# 18                  R и Python — достойные соперники?
# 19   Анализируя криптовалютные рынки с помощью Python
#
#                                      link
# 0   /ru/company/netologyru/news/t/594683/
# 1           /ru/company/otus/blog/331746/
# 2           /ru/company/otus/blog/331998/
# 3                        /ru/post/670668/
# 4                        /ru/post/556042/
# 5                        /ru/post/520204/
# 6    /ru/company/sbercloud/news/t/584084/
# 7                        /ru/post/228187/
# 8                        /ru/post/236757/
# 9                        /ru/post/243967/
# 10                       /ru/post/248165/
# 11                       /ru/post/232879/
# 12                       /ru/post/249415/
# 13                       /ru/post/226641/
# 14                       /ru/post/231323/
# 15     /ru/company/newprolab/blog/339116/
# 16                       /ru/post/340698/
# 17                       /ru/post/654407/
# 18         /ru/company/piter/blog/263457/
# 19         /ru/company/wirex/blog/406363/

# %% [markdown]
# ## Дополнительная часть (необязательная)

# %% [markdown]
# Функция из обязательной части задания должна быть расширена следующим образом:
# - кроме списка ключевых слов для поиска необходимо объявить параметр с количеством страниц поисковой выдачи. Т.е. при передаче в функцию аргумента `4` необходимо получить материалы с первых 4 страниц результатов;
# - в датафрейме должны быть столбцы с полным текстом найденных материалов и количеством лайков:
# ```
# <дата> - <заголовок> - <ссылка на материал> - <текст материала> - <количество лайков>
# ```

# %% [markdown]
# #### ПРИМЕЧАНИЕ
# Домашнее задание сдается ссылкой [Google Colab](https://colab.research.google.com/).
# Не сможем проверить или помочь, если вы пришлете:
# - файлы;
# - архивы;
# - скриншоты кода.
#
# Все обсуждения и консультации по выполнению домашнего задания ведутся только на соответствующем канале в slack.
#
# ##### Как правильно задавать вопросы аспирантам, преподавателям и коллегам?
# Прежде чем задать вопрос необходимо попробовать найти ответ самому в интернете. Навык самостоятельного поиска информации – один из важнейших, и каждый практикующий специалист любого уровня это делает каждый день.
#
# Любой вопрос должен быть сформулирован по алгоритму:
# 1) Что я делаю?
# 2) Какого результата я ожидаю?
# 3) Как фактический результат отличается от ожидаемого?
# 4) Что я уже попробовал сделать, чтобы исправить проблему?
#
# По возможности, прикрепляйте к вопросу скриншоты, либо ссылки на код. Оставляйте только проблемный и воспроизводимый участок кода, все решение выкладывать не допускается.
